# %%
# %pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/envs/app.py/lib/python3.14/site-packages (2.0.49)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/app.py/lib/python3.14/site-packages (from sqlalchemy) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey, Date
from sqlalchemy.orm import declarative_base, relationship
from datetime import date

db_name = 'travel_planner.db'

#This is to delete the old file and create a new one

# if os.path.exists(db_name):
#         os.remove(db_name)
#         print(f"{db_name} file has been deleted!")
# else:
#     print("No file to be deleted!")

# Base class for our classes definitions
Base = declarative_base()

# Table 1 Country
class Country(Base):
    __tablename__ = 'Country'
    
    id = Column(Integer, primary_key=True)
    country = Column(String, nullable=False)
    population = Column(String, unique=True, nullable=False)
    continent = Column(String, nullable=False)
    
    # Relationship between contries and cities
    cities = relationship("Cities", back_populates="country")
    
    def __repr__(self):
        return f"<Country(country='{self.country}', population='{self.population}')>"

# Table 2
class Destination(Base):
    __tablename__ = 'Destinations'
    
    id = Column(Integer, primary_key=True)
    city = Column(String, nullable=False)
    country = Column(String, nullable=False)
    
    # Relationship: A destination can be part of multiple trips
    country = relationship("country", back_populates="country")

    def __repr__(self):
        return f"<Destination(city='{self.city}', country='{self.country}')>"

# Table 3: Vibe
class Vibe(Base):
    __tablename__ = 'Vibe'
    
    id = Column(Integer, primary_key=True)
    activities = Column(String, nullable=False)
    

    def __repr__(self):
        return f"<Vibe(vibe={self.vibe}, destination_id={self.destination_id})>"


# Create the SQLite engine. echo=True will print the SQL commands generated under the hood.
engine = create_engine('sqlite:///travel_planner.db', echo=True)

# This command actually creates the database file and all the tables defined above
Base.metadata.create_all(engine)

print("\nSuccess: travel_planner.db and all connected tables have been created!")
# Out:
# 2026-05-03 11:46:07,055 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-03 11:46:07,055 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Country")
# 2026-05-03 11:46:07,056 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-03 11:46:07,057 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Country")
# 2026-05-03 11:46:07,057 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-03 11:46:07,057 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Destinations")
# 2026-05-03 11:46:07,058 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-03 11:46:07,058 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Destinations")
# 2026-05-03 11:46:07,058 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-03 11:46:07,059 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Vibe")
# 2026-05-03 11:46:07,059 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-03 11:46:07,059 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Vibe")
# 2026-05-03 11:46:07,060 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-03 11:46:07,060 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Country" (
# 	id INTEGER NOT NULL,
# 	country VARCHAR NOT NULL,
# 	population VARCHAR NOT NULL,
# 	PRIMARY KEY (id),
# 	UNIQUE (population)
# )
#
#
# 2026-05-03 11:46:07,061 INFO sqlalchemy.engine.Engine [no key 0.00024s] ()
# 2026-05-03 11:46:07,062 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Destinations" (
# 	id INTEGER NOT NULL,
# 	city VARCHAR NOT NULL,
# 	continent VARCHAR NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-05-03 11:46:07,062 INFO sqlalchemy.engine.Engine [no key 0.00032s] ()
# 2026-05-03 11:46:07,064 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Vibe" (
# 	id INTEGER NOT NULL,
# 	activities VARCHAR NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-05-03 11:46:07,064 INFO sqlalchemy.engine.Engine [no key 0.00034s] ()
# 2026-05-03 11:46:07,065 INFO sqlalchemy.engine.Engine COMMIT
#
# Success: travel_planner.db and all connected tables have been created!
