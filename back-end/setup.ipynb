# %%
# %pip install sqlalchemy

# %%
import os
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey
from sqlalchemy.orm import declarative_base, relationship

db_name = 'travel_planner.db'

# Delete old database file for a clean slate
if os.path.exists(db_name):
    os.remove(db_name)
    print(f"{db_name} file has been deleted!")
else:
    print("No file to be deleted!")

Base = declarative_base()

# ---------------------------------------------------------
# TABLE 1: Destinations
# ---------------------------------------------------------
class Destination(Base):
    __tablename__ = 'Destinations'
    
    DestinationID = Column(Integer, primary_key=True)
    CityName = Column(String, nullable=False)
    Country = Column(String, nullable=False)
    Description = Column(String, nullable=False)
    
    # Relationships point to the link classes
    activities = relationship("Destination_Activity", back_populates="destination")
    vibes = relationship("Destination_Vibe", back_populates="destination")

    def __repr__(self):
        return f"<Destination(City='{self.CityName}', Country='{self.Country}')>"


# ---------------------------------------------------------
# TABLE 2: Activities
# ---------------------------------------------------------
class Activity(Base):
    __tablename__ = 'Activities'
    
    ActivityID = Column(Integer, primary_key=True)
    ActivityName = Column(String, nullable=False)

    # Relationship pointing backward via the link class
    destinations = relationship("Destination_Activity", back_populates="activity")

    def __repr__(self):
        return f"<Activity(Name='{self.ActivityName}')>"


# ---------------------------------------------------------
# TABLE 3: Destinations_Activities (Link table with data)
# ---------------------------------------------------------
class Destination_Activity(Base):
    __tablename__ = 'Destinations_Activities'
    
    DestinationID = Column(Integer, ForeignKey('Destinations.DestinationID'), primary_key=True)
    ActivityID = Column(Integer, ForeignKey('Activities.ActivityID'), primary_key=True)
    
    # Extra data column
    Spotlight_Description = Column(String) 
    
    # Relationships mapping back to the parent tables
    destination = relationship("Destination", back_populates="activities")
    activity = relationship("Activity", back_populates="destinations")


# ---------------------------------------------------------
# TABLE 4: Travel_Vibes
# ---------------------------------------------------------
class Travel_Vibe(Base):
    __tablename__ = 'Travel_Vibes'
    
    VibeID = Column(Integer, primary_key=True)
    VibeName = Column(String, nullable=False)
    
    # Relationship pointing backward via the link class
    destinations = relationship("Destination_Vibe", back_populates="vibe")
    
    def __repr__(self):
        return f"<Vibe(Name='{self.VibeName}')>"


# ---------------------------------------------------------
# TABLE 5: Destination_Vibes (Pure Relational link table)
# ---------------------------------------------------------
class Destination_Vibe(Base):
    __tablename__ = 'Destination_Vibes'
    
    DestinationID = Column(Integer, ForeignKey('Destinations.DestinationID'), primary_key=True)
    VibeID = Column(Integer, ForeignKey('Travel_Vibes.VibeID'), primary_key=True)
    
    # Relationships mapping back to the parent tables
    destination = relationship("Destination", back_populates="vibes")
    vibe = relationship("Travel_Vibe", back_populates="destinations")


# ---------------------------------------------------------
# BUILD THE DATABASE
# ---------------------------------------------------------
engine = create_engine(f'sqlite:///{db_name}', echo=True)

Base.metadata.create_all(engine)

print(f"\nSuccess: {db_name} and all connected tables have been created!")
# Out:
# travel_planner.db file has been deleted!
# 2026-05-12 15:17:13,518 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-12 15:17:13,518 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Destinations")
# 2026-05-12 15:17:13,519 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,520 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Destinations")
# 2026-05-12 15:17:13,520 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,520 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Activities")
# 2026-05-12 15:17:13,521 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,521 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Activities")
# 2026-05-12 15:17:13,522 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,523 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Destinations_Activities")
# 2026-05-12 15:17:13,523 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,523 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Destinations_Activities")
# 2026-05-12 15:17:13,524 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,524 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Travel_Vibes")
# 2026-05-12 15:17:13,524 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,525 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Travel_Vibes")
# 2026-05-12 15:17:13,525 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,525 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Destination_Vibes")
# 2026-05-12 15:17:13,525 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,527 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Destination_Vibes")
# 2026-05-12 15:17:13,527 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-12 15:17:13,527 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Destinations" (
# 	"DestinationID" INTEGER NOT NULL,
# 	"CityName" VARCHAR NOT NULL,
# 	"Country" VARCHAR NOT NULL,
# 	"Description" VARCHAR NOT NULL,
# 	PRIMARY KEY ("DestinationID")
# )
#
#
# 2026-05-12 15:17:13,528 INFO sqlalchemy.engine.Engine [no key 0.00018s] ()
# 2026-05-12 15:17:13,528 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Activities" (
# 	"ActivityID" INTEGER NOT NULL,
# 	"ActivityName" VARCHAR NOT NULL,
# 	PRIMARY KEY ("ActivityID")
# )
#
#
# 2026-05-12 15:17:13,529 INFO sqlalchemy.engine.Engine [no key 0.00023s] ()
# 2026-05-12 15:17:13,530 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Travel_Vibes" (
# 	"VibeID" INTEGER NOT NULL,
# 	"VibeName" VARCHAR NOT NULL,
# 	PRIMARY KEY ("VibeID")
# )
#
#
# 2026-05-12 15:17:13,530 INFO sqlalchemy.engine.Engine [no key 0.00034s] ()
# 2026-05-12 15:17:13,532 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Destinations_Activities" (
# 	"DestinationID" INTEGER NOT NULL,
# 	"ActivityID" INTEGER NOT NULL,
# 	"Spotlight_Description" VARCHAR,
# 	PRIMARY KEY ("DestinationID", "ActivityID"),
# 	FOREIGN KEY("DestinationID") REFERENCES "Destinations" ("DestinationID"),
# 	FOREIGN KEY("ActivityID") REFERENCES "Activities" ("ActivityID")
# )
#
#
# 2026-05-12 15:17:13,533 INFO sqlalchemy.engine.Engine [no key 0.00040s] ()
# 2026-05-12 15:17:13,534 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Destination_Vibes" (
# 	"DestinationID" INTEGER NOT NULL,
# 	"VibeID" INTEGER NOT NULL,
# 	PRIMARY KEY ("DestinationID", "VibeID"),
# 	FOREIGN KEY("DestinationID") REFERENCES "Destinations" ("DestinationID"),
# 	FOREIGN KEY("VibeID") REFERENCES "Travel_Vibes" ("VibeID")
# )
#
#
# 2026-05-12 15:17:13,534 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2026-05-12 15:17:13,535 INFO sqlalchemy.engine.Engine COMMIT
#
# Success: travel_planner.db and all connected tables have been created!
